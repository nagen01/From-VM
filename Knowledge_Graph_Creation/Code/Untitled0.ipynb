# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
from pprint import pprint

# %%
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', '')]

# %% [markdown]
# SERIOUS STUFFF!!!!!!

# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 162

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 42,
#          'PERSON': 79,
#          'DATE': 25,
#          'GPE': 9,
#          'NORP': 2,
#          'CARDINAL': 3,
#          'LOC': 1,
#          'ORDINAL': 1})

# %%
[(x.text, x.label_) for x in article.ents]
# Out:
# [('F.B.I.', 'ORG'),
#  ('Peter Strzok', 'PERSON'),
#  ('Texts', 'ORG'),
#  ('The New York Times', 'ORG'),
#  ('InLog InToday', 'ORG'),
#  ('Peter Strzok', 'PERSON'),
#  ('Texts', 'ORG'),
#  ('byContinue', 'PERSON'),
#  ('Peter Strzok', 'PERSON'),
#  ('Texts', 'ORG'),
#  ('FiredPeter Strzok', 'ORG'),
#  ('F.B.I.', 'ORG'),
#  ('Trump', 'PERSON'),
#  ('The New York TimesBy Adam', 'ORG'),
#  ('Michael S. SchmidtAug', 'PERSON'),
#  ('13', 'DATE'),
#  ('2018WASHINGTON', 'GPE'),
#  ('Peter Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Trump', 'PERSON'),
#  ('Hillary Clinton', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('Strzok', 'PERSON'),
#  ('Monday', 'DATE'),
#  ('Trump', 'PERSON'),
#  ('2016', 'DATE'),
#  ('F.B.I.', 'ORG'),
#  ('Lisa Page', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('Strzok', 'PERSON'),
#  ('20 years', 'DATE'),
#  ('F.B.I.', 'ORG'),
#  ('the early months', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Trump', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('last summer', 'DATE'),
#  ('Robert S. Mueller III', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Monday', 'DATE'),
#  ('Trump', 'PERSON'),
#  ('June', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Hillary Clinton', 'PERSON'),
#  ('2016', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('Office of Professional Responsibility', 'ORG'),
#  ('Strzok', 'PERSON'),
#  ('60 days', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('House', 'ORG'),
#  ('July', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('David Bowdich', 'PERSON'),
#  ('the Office of Professional Responsibility', 'ORG'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Strzok', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Bowdich', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Christopher A. Wray', 'PERSON'),
#  ('Aitan Goelman', 'ORG'),
#  ('Strzok', 'PERSON'),
#  ('Wray', 'PERSON'),
#  ('Congress', 'ORG'),
#  ('F.B.I.', 'ORG'),
#  ('Goelman', 'PERSON'),
#  ('Americans', 'NORP'),
#  ('Goelman', 'PERSON'),
#  ('Page', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('Page', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Michael E. Horowitz', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('just weeks', 'DATE'),
#  ('2016', 'DATE'),
#  ('Horowitz', 'PERSON'),
#  ('Hundreds', 'CARDINAL'),
#  ('over months', 'DATE'),
#  ('Trump', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('Trump', 'PERSON'),
#  ('Horowitz', 'PERSON'),
#  ('Mueller', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Page', 'PERSON'),
#  ('Mueller', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('May', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Clinton', 'PERSON'),
#  ('Midyear Exam', 'LOC'),
#  ('Anthony D. Weiner', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Trump', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('nearly a month', 'DATE'),
#  ('Weiner', 'PERSON'),
#  ('Horowitz', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Clinton', 'PERSON'),
#  ('Strzok', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('Midyear', 'DATE'),
#  ('Weiner', 'ORG'),
#  ('Strzok', 'PERSON'),
#  ('last month', 'DATE'),
#  ('Today', 'DATE'),
#  ('James B. Comey', 'PERSON'),
#  ('F.B.I.', 'ORG'),
#  ('Congress', 'ORG'),
#  ('days', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('last month', 'DATE'),
#  ('Strzok', 'PERSON'),
#  ('Russia', 'GPE'),
#  ('second', 'ORDINAL'),
#  ('F.B.I.', 'ORG'),
#  ('March', 'DATE'),
#  ('Andrew G. McCabe', 'PERSON'),
#  ('McCabe', 'PERSON'),
#  ('48', 'DATE'),
#  ('Georgetown University', 'ORG'),
#  ('Army', 'ORG'),
#  ('F.B.I.', 'ORG'),
#  ('F.B.I.', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('C.I.A.', 'ORG'),
#  ('China', 'GPE'),
#  ('Russian', 'NORP'),
#  ('the United States', 'GPE'),
#  ('ed columnistseditorialsop-ed', 'PERSON'),
#  ('Contributorsletterssunday', 'DATE'),
#  ('artsart & designbooksdancemoviesmusicPop Culturetelevisiontheaterwatchingvideo',
#   'ORG'),
#  ('CenterWirecutterLive EventsThe Learning Networktools & servicesN.Y.C.',
#   'ORG'),
#  ('ed columnistseditorialsop-ed', 'PERSON'),
#  ('Contributorsletterssunday', 'DATE'),
#  ('artsart & designbooksdancemoviesmusicPop Culturetelevisiontheaterwatchingvideo',
#   'ORG'),
#  ('CenterWirecutterLive EventsThe Learning Networktools & servicesN.Y.C.',
#   'ORG'),
#  ('The New York Times', 'ORG'),
#  ('ServiceTerms of SaleSite MapHelpSubscriptions', 'ORG')]

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Strzok', 29), ('F.B.I.', 19), ('Trump', 13)]

# %%
sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# A spokeswoman for the F.B.I. did not respond to a message seeking comment about why Mr. Strzok was dismissed rather than demoted.

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">A spokeswoman for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  did not respond to a message seeking comment about why Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was dismissed rather than demoted.</div>

# %%
displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="990629e375894365a967ab53557b211d-0" class="displacy" width="2690" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">spokeswoman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">F.B.I.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">respond</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">message</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">seeking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">comment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">why</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Strzok</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">dismissed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">rather</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">than</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">demoted.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-990629e375894365a967ab53557b211d-0-0" stroke-width="2px" d="M70,362.0 C70,302.0 145.0,302.0 145.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-990629e375894365a967ab53557b211d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-990629e375894365a967ab53557b211d-0-1" stroke-width="2px" d="M190,362.0 C190,2.0 890.0,2.0 890.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-990629e375894365a967ab53557b211d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,364.0 L182,352.0 198,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-990629e375894365a967ab53557b211d-0-2" stroke-width="2px" d="M190,362.0 C190,302.0 265.0,302.0 265.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-990629e375894365a967ab53557b211d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M265.0,364.0 L273.0,352.0 257.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-990629e375894365a967ab53557b211d-0-3" stroke-width="2px" d="M430,362.0 C430,302.0 505.0,302.0 505.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-990629e375894365a967ab53557b211d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-ar

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('spokeswoman', 'NOUN', 'spokeswoman'),
#  ('F.B.I.', 'PROPN', 'F.B.I.'),
#  ('respond', 'VERB', 'respond'),
#  ('message', 'NOUN', 'message'),
#  ('seeking', 'VERB', 'seek'),
#  ('comment', 'NOUN', 'comment'),
#  ('Mr.', 'PROPN', 'Mr.'),
#  ('Strzok', 'PROPN', 'Strzok'),
#  ('dismissed', 'VERB', 'dismiss'),
#  ('demoted', 'VERB', 'demote')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[20])).ents])
# Out:
# {'F.B.I.': 'ORG', 'Strzok': 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[20]])
# Out:
# [(A, 'O', ''), (spokeswoman, 'O', ''), (for, 'O', ''), (the, 'O', ''), (F.B.I., 'B', 'ORG'), (did, 'O', ''), (not, 'O', ''), (respond, 'O', ''), (to, 'O', ''), (a, 'O', ''), (message, 'O', ''), (seeking, 'O', ''), (comment, 'O', ''), (about, 'O', ''), (why, 'O', ''), (Mr., 'O', ''), (Strzok, 'B', 'PERSON'), (was, 'O', ''), (dismissed, 'O', ''), (rather, 'O', ''), (than, 'O', ''), (demoted, 'O', ''), (., 'O', '')]

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is Fired -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                            SectionsSEARCHSkip to contentSkip to site indexPoliticsLog
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     InLog InToday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s PaperPolitics|F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is Firedhttps://nyti.ms/2OtNre3AdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reading the main storyF.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FiredPeter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired.Credit...T.J. Kirkpatrick for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York TimesBy Adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Goldman and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael S. SchmidtAug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior counterintelligence agent who disparaged President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in inflammatory text messages and helped oversee the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  email and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bo
