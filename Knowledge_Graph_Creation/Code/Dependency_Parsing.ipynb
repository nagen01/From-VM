# %%
# Import the below packages.

import spacy
from spacy.lang.en import English
nlp = spacy.load("en_core_web_sm")
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
#from nltk.stem.wordnet import WordNetLemmatizer
#import textacy
#from textacy.extract import subject_verb_object_triples
#from bs4 import BeautifulSoup
#import requests
import re
import os

# %%
data_dir ='/home/nb01/C_Drive/Knowledge_Graph_Creation/Dataset/PetroleumPreprocessedDataset/' 
TEXTS = [open(data_dir+f).read() for f in os.listdir(data_dir)]

# %%
os.listdir(data_dir)
# Out:
# ['Alkane.txt', 'Alaska.txt']

# %%
len(TEXTS)
# Out:
# 2

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
OBJECTS = ["dobj", "dative", "attr", "oprd"]

# %%
#Every function has a set of rules to extract Subjects and Objects based on the rules 

def getSubsFromConjunctions(subs):
    moreSubs = []
    for sub in subs:
        # rights is a generator
        rights = list(sub.rights)
        rightDeps = {tok.lower_ for tok in rights}
        if "and" in rightDeps:
            moreSubs.extend([tok for tok in rights if tok.dep_ in SUBJECTS or tok.pos_ == "NOUN"])
            if len(moreSubs) > 0:
                moreSubs.extend(getSubsFromConjunctions(moreSubs))
    return moreSubs

def getObjsFromConjunctions(objs):
    moreObjs = []
    for obj in objs:
        # rights is a generator
        rights = list(obj.rights)
        rightDeps = {tok.lower_ for tok in rights}
        if "and" in rightDeps:
            moreObjs.extend([tok for tok in rights if tok.dep_ in OBJECTS or tok.pos_ == "NOUN"])
            if len(moreObjs) > 0:
                moreObjs.extend(getObjsFromConjunctions(moreObjs))
    return moreObjs

def getVerbsFromConjunctions(verbs):
    moreVerbs = []
    for verb in verbs:
        rightDeps = {tok.lower_ for tok in verb.rights}
        if "and" in rightDeps:
            moreVerbs.extend([tok for tok in verb.rights if tok.pos_ == "VERB"])
            if len(moreVerbs) > 0:
                moreVerbs.extend(getVerbsFromConjunctions(moreVerbs))
    return moreVerbs

def findSubs(tok):
    head = tok.head
    while head.pos_ != "VERB" and head.pos_ != "NOUN" and head.head != head:
        head = head.head
    if head.pos_ == "VERB":
        subs = [tok for tok in head.lefts if tok.dep_ == "SUB"]
        if len(subs) > 0:
            verbNegated = isNegated(head)
            subs.extend(getSubsFromConjunctions(subs))
            return subs, verbNegated
        elif head.head != head:
            return findSubs(head)
    elif head.pos_ == "NOUN":
        return [head], isNegated(tok)
    return [], False

def isNegated(tok):
    negations = {"no", "not", "n't", "never", "none"}
    for dep in list(tok.lefts) + list(tok.rights):
        if dep.lower_ in negations:
            return True
    return False

def findSVs(tokens):
    svs = []
    verbs = [tok for tok in tokens if tok.pos_ == "VERB"]
    for v in verbs:
        subs, verbNegated = getAllSubs(v)
        if len(subs) > 0:
            for sub in subs:
                svs.append((sub.orth_, "!" + v.orth_ if verbNegated else v.orth_))
    return svs

def getObjsFromPrepositions(deps):
    objs = []
    for dep in deps:
        if dep.pos_ == "ADP" and dep.dep_ == "prep":
            objs.extend([tok for tok in dep.rights if tok.dep_  in OBJECTS or (tok.pos_ == "PRON" and tok.lower_ == "me")])
    return objs

def getObjsFromAttrs(deps):
    for dep in deps:
        if dep.pos_ == "NOUN" and dep.dep_ == "attr":
            verbs = [tok for tok in dep.rights if tok.pos_ == "VERB"]
            if len(verbs) > 0:
                for v in verbs:
                    rights = list(v.rights)
                    objs = [tok for tok in rights if tok.dep_ in OBJECTS]
                    objs.extend(getObjsFromPrepositions(rights))
                    if len(objs) > 0:
                        return v, objs
    return None, None

def getObjFromXComp(deps):
    for dep in deps:
        if dep.pos_ == "VERB" and dep.dep_ == "xcomp":
            v = dep
            rights = list(v.rights)
            objs = [tok for tok in rights if tok.dep_ in OBJECTS]
            objs.extend(getObjsFromPrepositions(rights))
            if len(objs) > 0:
                return v, objs
    return None, None

def getAllSubs(v):
    verbNegated = isNegated(v)
    subs = [tok for tok in v.lefts if tok.dep_ in SUBJECTS and tok.pos_ != "DET"]
    if len(subs) > 0:
        subs.extend(getSubsFromConjunctions(subs))
    else:
        foundSubs, verbNegated = findSubs(v)
        subs.extend(foundSubs)
    return subs, verbNegated

def getAllObjs(v):
    # rights is a generator
    rights = list(v.rights)
    objs = [tok for tok in rights if tok.dep_ in OBJECTS]
    objs.extend(getObjsFromPrepositions(rights)
    potentialNewVerb, potentialNewObjs = getObjFromXComp(rights)
    if potentialNewVerb is not None and potentialNewObjs is not None and len(potentialNewObjs) > 0:
        objs.extend(potentialNewObjs)
        v = potentialNewVerb
    if len(objs) > 0:
        objs.extend(getObjsFromConjunctions(objs))
    return v, objs

def findSVOs(tokens):
    svos = []
    verbs = [tok for tok in tokens if tok.pos_ == "VERB" and tok.dep_ != "aux"]
    for v in verbs:
        subs, verbNegated = getAllSubs(v)
        # hopefully there are subs, if not, don't examine this verb any longer
        if len(subs) > 0:
            v, objs = getAllObjs(v)
            for sub in subs:
                for obj in objs:
                    objNegated = isNegated(obj)
                    svos.append((sub.lower_, "!" + v.lower_ if verbNegated or objNegated else v.lower_, obj.lower_))
    return svos
def printDeps(toks):
    for tok in toks:
        print(tok.orth_, tok.dep_, tok.pos_, tok.head.orth_, [t.orth_ for t in tok.lefts], [t.orth_ for t in tok.rights])
# Out:
#   File "<ipython-input-6-5eccff644eb5>", line 116
#     potentialNewVerb, potentialNewObjs = getObjFromXComp(rights)
#                    ^
# SyntaxError: invalid syntax

# %%
for i,text in enumerate(TEXTS):
    for sent in sent_tokenize(text):
        #svos = findSVOs(sent)
        print(sent)
        #print(svos)

# %%
for i,text in enumerate(TEXTS):
    #count = 0
    for sentence in nltk.sent_tokenize(text):
        doc = nlp(sentence)
        #count += 1
        #while count < 2:
        print(doc)
        print('\n')
# Out:
# In organic chemistry alkane paraffin acyclic saturated hydrocarbon .
#
#
# In words alkane consists hydrogen carbon atoms arranged tree structure carbon–carbon bonds single .
#
#
# Alkanes general chemical formula CnH2n2 .
#
#
# The alkanes range complexity simplest case methane n 1 arbitrarily large complex molecules like pentacontane 6ethyl2methyl5 octane isomer tetradecane .
#
#
# IUPAC defines alkanes acyclic branched unbranched hydrocarbons general formula CnH2n2 therefore consisting entirely hydrogen atoms saturated carbon atoms .
#
#
# However sources use term denote saturated hydrocarbon including either monocyclic polycyclic despite different general formula .
#
#
# In alkane carbon atom sp3hybridized 4 sigma bonds hydrogen atom joined one carbon atoms .
#
#
# The longest series linked carbon atoms molecule known carbon skeleton carbon backbone .
#
#
# The number carbon atoms may considered size alkane .
#
#
# One group higher alkanes waxes solids standard ambient temperature pressure number carbon atoms carbon backbone greater 17 .
#
#
# With repeated –CH2 units alkanes constitute homologous series organic compounds members differ molecular mass multiples 14.03 u .
#
#
# Methane produced methanogenic bacteria longchain alkanes function pheromones certain animal species protective waxes plants fungi .
#
#
# Nevertheless alkanes much biological activity .
#
#
# They viewed molecular trees upon hung activereactive functional groups biological molecules .
#
#
# The alkanes two main commercial sources petroleum natural gas .
#
#
# An alkyl group alkanebased molecular fragment bears one open valence bonding .
#
#
# They generally abbreviated symbol organyl group R although Alk sometimes used specifically symbolize alkyl group .
#
#
# Saturated hydrocarbons hydrocarbons single covalent bonds carbons .
#
#
# They According definition IUPAC former two alkanes whereas third group called cycloalkanes .
#
#
# Saturated hydrocarbons also combine linear cyclic branching structures general formula CnH2n−2k2 k number independent loops .
#
#
# Alkanes acyclic ones corresponding k 0 .
#
#
# Alkanes three carbon atoms arranged various different ways forming structural isomers .
#
#
# The simplest isomer alkane one carbon atoms arranged single chain branches .
#
#
# This isomer sometimes called nisomer .
#
#
# However chain carbon atoms may also branched one points .
#
#
# The number possible isomers increases rapidly number carbon atoms .
#
#
# For example acyclic alkanes Branched alkanes chiral .
#
#
# For example 3methylhexane higher homologues chiral due stereogenic center carbon atom number 3 .
#
#
# In addition alkane isomers chain carbon atoms may form one loops .
#
#
# Such compounds called cycloalkanes .
#
#
# Stereoisomers cyclic compounds excluded calculating number isomers .
#
#
# The IUPAC nomenclature alkanes based identifying hydrocarbon chains .
#
#
# Unbranched saturated hydrocarbon chains named systematically Greek numerical prefix denoting number carbons suffix ane .
#
#
# In 1866 August Wilhelm von Hofmann suggested systematizing nomenclature using whole sequence vowels e u create suffixes ane ene ine one une hydrocarbons CnH2n2 CnH2n CnH2n−2 CnH2n−4 CnH2n−6 .
#
#
# Now first three name hydrocarbons single double triple bonds one represents ketone ol represents alcohol OH group oxy means ether refers oxygen two carbons methoxymethane IUPAC name dimethyl ether .
#
#
# It difficult impossible find compounds one IUPAC name .
#
#
# This shorter chains attached longer chains prefixes convention includes brackets .
#
#
# Numbers name referring carbon group attached low possible 1 implied usually omitted names organic compounds one sidegroup .
#
#
# Symmetric compounds two ways arriving name .
#
#
# Straightchain alkanes sometimes indicated prefix n nonlinear isomer exists .
#
#
# Although strictly necessary usage still common cases important difference properties straightchain branchedchain isomers e.g.
#
#
# nhexane 2 3methylpentane .
#
#
# Alternative names group linear paraffins nparaffins .
#
#
# The members series named follows The first four names derived methanol ether propionic acid butyric acid respectively .
#
#
# Alkanes five carbon atoms named adding suffix ane appropriate numerical multiplier prefix elision terminal vowel basic numerical term .
#
#
# Hence pentane C5H12 hexane C6H14 heptane C7H16 octane C8H18 etc .
#
#
# The prefix generally Greek however alkanes carbon atom count ending nine example nonane use Latin prefix non .
#
#
# For complete list see List alkanes .
#
#
# Simple branched alkanes often common name using prefix distinguish linear alkanes example npentane isopentane neopentane .
#
#
# IUPAC naming conventions used produce systematic name .
#
#
# The key steps naming complicated branched alkanes follows Though technically distinct alkanes class hydrocarbons referred cyclic alkanes .
#
#
# As description implies contain one rings .
#
#
# Simple cycloalkanes prefix cyclo distinguish alkanes .
#
#
# Cycloalkanes named per acyclic counterparts respect number carbon atoms backbones e.g.
#
#
# cyclopentane cycloalkane 5 carbon atoms like pentane joined fivemembered ring .
#
#
# In similar manner propane cyclopropane butane cyclobutane etc .
#
#
# Substituted cycloalkanes named similarly substituted alkanes – cycloalkane ring stated substituents according position ring numbering decided Cahn–Ingold–Prelog priority rules .
#
#
# The trivial name alkanes paraffins .
#
#
# Together alkanes known paraffin series .
#
#
# Trivial names compounds usually historical artifacts .
#
#
# They coined development systematic names retained due familiar usage industry .
#
#
# Cycloalkanes also called naphthenes .
#
#
# It almost certain term paraffin stems petrochemical industry .
#
#
# Branchedchain alkanes called isoparaffins .
#
#
# The use term paraffin general term often distinguish pure compounds mixtures isomers i.e.
#
#
# compounds chemical formula e.g.
#
#
# pentane isopentane .
#
#
# The following trivial names retained IUPAC system Some nonIUPAC trivial names occasionally used All alkanes colorless .
#
#
# Alkanes lowest molecular weights gasses intermediate molecular weight liquids heaviest waxy solids .
#
#
# Alkanes experience intermolecular van der Waals forces .
#
#
# Stronger intermolecular van der Waals forces give rise greater boiling points alkanes .
#
#
# There two determinants strength van der Waals forces Under standard conditions CH4 C4H10 alkanes gaseous C5H12 C17H36 liquids C18H38 solids .
#
#
# As boiling point alkanes primarily determined weight surprise boiling point almost linear relationship size molecule .
#
#
# As rule thumb boiling point rises 20–30 °C carbon added chain rule applies homologous series .
#
#
# A straightchain alkane boiling point higher branchedchain alkane due greater surface area contact thus greater van der Waals forces adjacent molecules .
#
#
# For example compare isobutane nbutane boil −12 0 °C 22dimethylbutane 23dimethylbutane boil 50 58 °C respectively .
#
#
# For latter case two molecules 23dimethylbutane lock better crossshaped 22dimethylbutane hence greater van der Waals forces .
#
#
# On hand cycloalkanes tend higher boiling points linear counterparts due locked conformations molecules give plane intermolecular contact .
#
#
# The melting points alkanes follow similar trend boiling points reason outlined .
#
#
# That larger molecule higher melting point .
#
#
# There one significant difference boiling points melting points .
#
#
# Solids rigid fixed structure liquids .
#
#
# This rigid structure requires energy break .
#
#
# Thus better put together solid structures require energy break apart .
#
#
# For alkanes seen graph .
#
#
# The oddnumbered alkanes lower trend melting points even numbered alkanes .
#
#
# This even numbered alkanes pack well solid phase forming wellorganized structure requires energy break apart .
#
#
# The oddnumbered alkanes pack less well looser organized solid packing structure requires less energy break apart .
#
#
# The melting points branchedchain alkanes either higher lower corresponding straightchain alkanes depending ability alkane question pack well solid phase This particularly true isoalkanes often melting points higher linear analogues .
#
#
# Alkanes conduct electricity way substantially polarized electric field .
#
#
# For reason form hydrogen bonds insoluble polar solvents water .
#
#
# Since hydrogen bonds individual water molecules aligned away alkane molecule coexistence alkane water leads increase molecular order .
#
#
# As significant bonding water molecules alkane molecules second law thermodynamics suggests reduction entropy minimized minimizing contact alkane water Alkanes said hydrophobic repel water .
#
#
# Their solubility nonpolar solvents relatively high property called lipophilicity .
#
#
# Different alkanes example miscible proportions among .
#
#
# The density alkanes usually increases number carbon atoms remains less water .
#
#
# Hence alkanes form upper layer alkane–water mixture .
#
#
# The molecular structure alkanes directly affects physical chemical characteristics .
#
#
# It derived electron configuration carbon four valence electrons .
#
#
# The carbon atoms alkanes always sp3hybridized say valence electrons said four equivalent orbitals derived combination 2s orbital three 2p orbitals .
#
#
# These orbitals identical energies arranged spatially form tetrahedron angle cos−1 ≈ 109.47° .
#
#
# An alkane molecule C–H C–C single bonds .
#
#
# The former result overlap sp3 orbital carbon 1s orbital hydrogen latter overlap two sp3 orbitals different carbon atoms .
#
#
# The bond lengths amount 1.09 × 10−10 C–H bond 1.54 × 10−10 C–C bond .
#
#
# The spatial arrangement bonds similar four sp3 orbitals—they tetrahedrally arranged angle 109.47° .
# Structural formulae represent bonds right angles one another common useful correspond reality .
#
#
# The structural formula bond angles usually sufficient completely describe geometry molecule .
#
#
# There degree freedom carbon–carbon bond torsion angle atoms groups bound atoms end bond .
#
#
# The spatial arrangement described torsion angles molecule known conformation .
#
#
# Ethane forms simplest case studying conformation alkanes one C–C bond .
#
#
# If one looks axis C–C bond one see socalled Newman projection .
#
#
# The hydrogen atoms front rear carbon atoms angle 120° resulting projection base tetrahedron onto flat plane .
#
#
# However torsion angle given hydrogen atom attached front carbon given hydrogen atom attached rear carbon vary freely 0° 360° .
#
#
# This consequence free rotation carbon–carbon single bond .
#
#
# Despite apparent freedom two limiting conformations important eclipsed conformation staggered conformation .
#
#
# The two conformations differ energy staggered conformation 12.6 kJmol lower energy eclipsed conformation .
#
#
# This difference energy two conformations known torsion energy low compared thermal energy ethane molecule ambient temperature .
#
#
# There constant rotation C–C bond .
#
#
# The time taken ethane molecule pass one staggered conformation next equivalent rotation one CH3 group 120° relative order 10−11 seconds .
#
#
# The case higher alkanes complex based similar principles antiperiplanar conformation always favored around carbon–carbon bond .
#
#
# For reason alkanes usually shown zigzag arrangement diagrams models .
#
#
# The actual structure always differ somewhat idealized forms differences energy conformations small compared thermal energy molecules Alkane molecules fixed structural form whatever models may suggest .
#
#
# Virtually organic compounds contain carbon–carbon carbon–hydrogen bonds show features alkanes spectra .
#
#
# Alkanes notable groups therefore absence characteristic spectroscopic features different functional group like –OH –CHO –COOH etc .
#
#
# The carbon–hydrogen stretching mode gives strong absorption 2850 2960 cm−1 carbon–carbon stretching mode absorbs 800 1300 cm−1 .
#
#
# The carbon–hydrogen bending modes depend nature group methyl groups show bands 1450 cm−1 1375 cm−1 methylene groups show bands 1465 cm−1 1450 cm−1 .
#
#
# Carbon chains four carbon atoms show weak absorption around 725 cm−1 .
#
#
# The proton resonances alkanes usually found δH 0.5–1.5 .
#
#
# The carbon13 resonances depend number hydrogen atoms attached carbon δC 8–30 15–55 20–60 quaternary .
#
#
# The carbon13 resonance quaternary carbon atoms characteristically weak due lack nuclear Overhauser effect long relaxation time missed weak samples samples run sufficiently long time .
#
#
# Alkanes high ionization energy molecular ion usually weak .
#
#
# The fragmentation pattern difficult interpret case branched chain alkanes carbon chain preferentially cleaved tertiary quaternary carbons due relative stability resulting free radicals .
#
#
# The fragment resulting loss single methyl group often absent fragments often spaced intervals fourteen mass units corresponding sequential loss CH2 groups .
#
#
# Alkanes weakly reactive chemical compounds .
#
#
# The acid dissociation constant values alkanes estimated range 50 70 depending extrapolation method hence extremely weak acids practically inert bases .
#
#
# They also extremely weak bases undergoing observable protonation pure sulfuric acid although superacids least millions times stronger known protonate give hypercoordinate alkanium ions .
#
#
# Similarly show reactivity strongest electrophilic reagents .
#
#
# By virtue strongly C–H bonds C–C bonds also relatively unreactive toward free radicals although many electrondeficient radicals react alkanes absence electronrich bonds .
#
#
# This inertness source term paraffins .
#
#
# In crude oil alkane molecules remained chemically unchanged millions years .
#
#
# Free radicals molecules unpaired electrons play large role reactions alkanes cracking reformation longchain alkanes converted shorterchain alkanes straightchain alkanes branchedchain isomers .
#
#
# Moreover redox reactions alkanes involving free radical intermediates particular oxygen halogens possible carbon atoms strongly reduced state case methane carbon lowest possible oxidation state .
#
#
# Reaction oxygen leads combustion without smoke producing carbon dioxide water .
#
#
# Free radical halogenation reactions occur halogens leading production haloalkanes .
#
#
# In addition alkanes shown interact bind certain transition metal complexes C–H bond activation reactions .
#
#
# In highly branched alkanes bond angle may differ significantly optimal value order allow different groups sufficient space .
#
#
# This causes tension molecule known steric hindrance substantially increase reactivity .
#
#
# However general perhaps surprisingly branching extensive enough make highly disfavorable 12 13alkyl–alkyl steric interactions unavoidable branched alkanes actually thermodynamically stable linear isomers .
#
#
# For example highly branched 2233tetramethylbutane 1.9 kcalmol stable linear isomer noctane .
#
#
# Due subtlety effect exact reasons rule vigorously debated chemical literature yet unsettled .
#
#
# Several explanations including stabilization branched alkanes electron correlation destabilization linear alkanes steric repulsion stabilization neutral hyperconjugation andor electrostatic effects advanced possibilities .
#
#
# The controversy related question whether traditional explanation hyperconjugation primary factor governing stability alkyl radicals .
#
#
# All alkanes react oxygen combustion reaction although become increasingly difficult ignite number carbon atoms increases .
#
#
# The general equation complete combustion In absence sufficient oxygen carbon monoxide even soot formed shown For example methane See alkane heat formation table detailed data .
#
#
# The standard enthalpy change combustion ΔcH⊖ alkanes increases 650 kJmol per CH2 group .
#
#
# Branchedchain alkanes lower values ΔcH⊖ straightchain alkanes number carbon atoms seen somewhat stable .
#
#
# Alkanes react halogens socalled free radical halogenation reaction .
#
#
# The hydrogen atoms alkane progressively replaced halogen atoms .
#
#
# Free radicals reactive species participate reaction usually leads mixture products .
#
#
# The reaction highly exothermic lead explosion .
#
#
# These reactions important industrial route halogenated hydrocarbons .
#
#
# There three steps Experiments shown halogenation produces mixture possible isomers indicating hydrogen atoms susceptible reaction .
#
#
# The mixture produced however statistical mixture Secondary tertiary hydrogen atoms preferentially replaced due greater stability secondary tertiary freeradicals .
#
#
# An example seen monobromination propane Cracking breaks larger molecules smaller ones .
#
#
# This done thermal catalytic method .
#
#
# The thermal cracking process follows homolytic mechanism formation freeradicals .
#
#
# The catalytic cracking process involves presence acid catalysts promote heterolytic breakage bonds yielding pairs ions opposite charges usually carbocation unstable hydride anion .
#
#
# Carbonlocalized free radicals cations highly unstable undergo processes chain rearrangement C–C scission position beta intra intermolecular hydrogen transfer hydride transfer .
#
#
# In types processes corresponding reactive intermediates permanently regenerated thus proceed selfpropagating chain mechanism .
#
#
# The chain reactions eventually terminated radical ion recombination .
#
#
# Dragan colleague first report isomerization alkanes .
#
#
# Isomerization reformation processes straightchain alkanes heated presence platinum catalyst .
#
#
# In isomerization alkanes become branchedchain isomers .
#
#
# In words lose carbons hydrogens keeping molecular weight .
#
#
# In reformation alkanes become cycloalkanes aromatic hydrocarbons giving hydrogen byproduct .
#
#
# Both processes raise octane number substance .
#
#
# Butane common alkane put process isomerization makes many branched alkanes high octane numbers .
#
#
# Alkanes react steam presence nickel catalyst give hydrogen .
#
#
# Alkanes chlorosulfonated nitrated although reactions require special conditions .
#
#
# The fermentation alkanes carboxylic acids technical importance .
#
#
# In Reed reaction sulfur dioxide chlorine light convert hydrocarbons sulfonyl chlorides .
#
#
# Nucleophilic Abstraction used separate alkane metal .
#
#
# Alkyl groups transferred one compound another transmetalation reactions .
#
#
# A mixture antimony pentafluoride fluorosulfonic acid called magic acid protonate alkanes .
#
#
# Alkanes form small portion atmospheres outer gas planets Jupiter Saturn Uranus Neptune .
#
#
# Titan satellite Saturn examined Huygens probe indicated Titan s atmosphere periodically rains liquid methane onto moon s surface .
#
#
# Also Titan Cassini mission imaged seasonal methaneethane lakes near polar regions Titan .
#
#
# Methane ethane also detected tail comet Hyakutake .
# Chemical analysis showed abundances ethane methane roughly equal thought imply ices formed interstellar space away Sun would evaporated volatile molecules .
#
#
# Alkanes also detected meteorites carbonaceous chondrites .
#
#
# Traces methane gas occur Earth s atmosphere produced primarily methanogenic microorganisms Archaea gut ruminants .
#
#
# The important commercial sources alkanes natural gas oil .
#
#
# Natural gas contains primarily methane ethane propane butane oil mixture liquid alkanes hydrocarbons .
#
#
# These hydrocarbons formed marine animals plants died sank bottom ancient seas covered sediments anoxic environment converted many millions years high temperatures high pressure current form .
#
#
# Natural gas resulted thereby example following reaction These hydrocarbon deposits collected porous rocks trapped beneath impermeable cap rocks comprise commercial oil fields .
#
#
# They formed millions years exhausted readily replaced .
#
#
# The depletion hydrocarbons reserves basis known energy crisis .
#
#
# Methane also present called biogas produced animals decaying matter possible renewable energy source .
#
#
# Alkanes low solubility water content oceans negligible however high pressures low temperatures methane cocrystallize water form solid methane clathrate .
#
#
# Although commercially exploited present time amount combustible energy known methane clathrate fields exceeds energy content natural gas oil deposits put together .
#
#
# Methane extracted methane clathrate therefore candidate future fuels .
#
#
# Acyclic alkanes occur nature various ways .
#
#
# Certain types bacteria metabolize alkanes prefer evennumbered carbon chains easier degrade oddnumbered chains .
#
#
# On hand certain archaea methanogens produce large quantities methane metabolism carbon dioxide oxidized organic compounds .
#
#
# The energy released oxidation hydrogen Methanogens also producers marsh gas wetlands release two billion tonnes methane per year—the atmospheric content gas produced nearly exclusively .
#
#
# The methane output cattle herbivores release 30 50 gallons per day termites also due methanogens .
#
#
# They also produce simplest alkanes intestines humans .
#
#
# Methanogenic archaea hence end carbon cycle carbon released back atmosphere fixed photosynthesis .
#
#
# It probable current deposits natural gas formed similar way .
#
#
# Alkanes also play role minor role biology three eukaryotic groups organisms fungi plants animals .
#
#
# Some specialized yeasts e.g.
#
#
# Candida tropicale Pichia sp.
#
#
# Rhodotorula sp.
#
#
# use alkanes source carbon energy .
#
#
# The fungus Amorphotheca resinae prefers longerchain alkanes aviation fuel cause serious problems aircraft tropical regions .
#
#
# In plants solid longchain alkanes found plant cuticle epicuticular wax many species rarely major constituents .
#
#
# They protect plant water loss prevent leaching important minerals rain protect bacteria fungi harmful insects .
#
#
# The carbon chains plant alkanes usually oddnumbered 27 33 carbon atoms length made plants decarboxylation evennumbered fatty acids .
#
#
# The exact composition layer wax speciesdependent changes also season environmental factors lighting conditions temperature humidity .
#
#
# More volatile shortchain alkanes also produced found plant tissues .
#
#
# The Jeffrey pine noted producing exceptionally high levels nheptane resin reason distillate designated zero point one octane rating .
#
#
# Floral scents also long known contain volatile alkane components nnonane significant component scent roses .
#
#
# Emission gaseous volatile alkanes ethane pentane hexane plants also documented low levels though generally considered major component biogenic air pollution .
#
#
# Edible vegetable oils also typically contain small fractions biogenic alkanes wide spectrum carbon numbers mainly 8 35 usually peaking low upper 20s concentrations dozens milligrams per kilogram sometimes hundred total alkane fraction .
#
#
# Alkanes found animal products although less important unsaturated hydrocarbons .
#
#
# One example shark liver oil approximately 14 pristane .
#
#
# They important pheromones chemical messenger materials insects depend communication .
#
#
# In species e.g .
#
#
# support beetle Xylotrechus colonus pentacosane 3methylpentaicosane 9methylpentaicosane transferred body contact .
#
#
# With others like tsetse fly Glossina morsitans morsitans pheromone contains four alkanes 2methylheptadecane 1721dimethylheptatriacontane 1519dimethylheptatriacontane 151923trimethylheptatriacontane acts smell longer distances .
#
#
# Waggledancing honey bees produce release two alkanes tricosane pentacosane .
#
#
# One example plant animal alkanes play role ecological relationship sand bee early spider orchid latter dependent pollination former .
#
#
# Sand bees use pheromones order identify mate case A. nigroaenea females emit mixture tricosane pentacosane heptacosane ratio 331 males attracted specifically odor .
#
#
# The orchid takes advantage mating arrangement get male bee collect disseminate pollen parts flower resemble appearance sand bees also produce large quantities three alkanes ratio female sand bees .
#
#
# As result numerous males lured blooms attempt copulate imaginary partner although endeavor crowned success bee allows orchid transfer pollen dispersed departure frustrated male different blooms .
#
#
# As stated earlier important source alkanes natural gas crude oil .
#
#
# Alkanes separated oil refinery fractional distillation processed many different products .
#
#
# The Fischer–Tropsch process method synthesize liquid hydrocarbons including alkanes carbon monoxide hydrogen .
#
#
# This method used produce substitutes petroleum distillates .
#
#
# There usually little need alkanes synthesized laboratory since usually commercially available .
#
#
# Also alkanes generally unreactive chemically biologically undergo functional group interconversions cleanly .
#
#
# When alkanes produced laboratory often sideproduct reaction .
#
#
# For example use nbutyllithium strong base gives conjugate acid nbutane sideproduct However times may desirable make section molecule alkanelike functionality using similar methods .
#
#
# For example ethyl group alkyl group attached hydroxy group gives ethanol alkane .
#
#
# To bestknown methods hydrogenation alkenes Alkanes alkyl groups also prepared directly alkyl halides Corey–House–Posner–Whitesides reaction .
#
#
# The Barton–McCombie deoxygenation removes hydroxyl groups alcohols e.g .
#
#
# Clemmensen reduction removes carbonyl groups aldehydes ketones form alkanes alkylsubstituted compounds e.g .
#
#
# The applications alkanes depend number carbon atoms .
#
#
# The first four alkanes used mainly heating cooking purposes countries electricity generation .
#
#
# Methane ethane main components natural gas normally stored gases pressure .
#
#
# It however easier transport liquids This requires compression cooling gas .
#
#
# Propane butane gases atmospheric pressure liquefied fairly low pressures commonly known liquified petroleum gas .
#
#
# Propane used propane gas burners fuel road vehicles butane space heaters disposable cigarette lighters .
#
#
# Both used propellants aerosol sprays .
#
#
# From pentane octane alkanes highly volatile liquids .
#
#
# They used fuels internal combustion engines vaporize easily entry combustion chamber without forming droplets would impair uniformity combustion .
#
#
# Branchedchain alkanes preferred much less prone premature ignition causes knocking straightchain homologues .
#
#
# This propensity premature ignition measured octane rating fuel 224trimethylpentane arbitrary value 100 heptane value zero .
#
#
# Apart use fuels middle alkanes also good solvents nonpolar substances .
#
#
# Alkanes nonane instance hexadecane liquids higher viscosity less less suitable use gasoline .
#
#
# They form instead major part diesel aviation fuel .
#
#
# Diesel fuels characterized cetane number cetane old name hexadecane .
#
#
# However higher melting points alkanes cause problems low temperatures polar regions fuel becomes thick flow correctly .
#
#
# Alkanes hexadecane upwards form important components fuel oil lubricating oil .
#
#
# In latter function work time anticorrosive agents hydrophobic nature means water reach metal surface .
#
#
# Many solid alkanes find use paraffin wax example candles .
#
#
# This confused however true wax consists primarily esters .
#
#
# Alkanes chain length approximately 35 carbon atoms found bitumen used example road surfacing .
#
#
# However higher alkanes little value usually split lower alkanes cracking .
#
#
# Some synthetic polymers polyethylene polypropylene alkanes chains containing hundreds thousands carbon atoms .
#
#
# These materials used innumerable applications billions kilograms materials made used year .
#
#
# Alkanes chemically inert apolar molecules reactive organic compounds .
#
#
# This inertness yields serious ecological issues released environment .
#
#
# Due lack functional groups low water solubility alkanes show poor bioavailability microorganisms .
#
#
# There however microorganisms possessing metabolic capacity utilize nalkanes carbon energy sources .
#
#
# Some bacterial species highly specialised degrading alkanes referred hydrocarbonoclastic bacteria .
#
#
# Methane flammable explosive dangerous inhale colorless odorless gas special caution must taken around methane .
#
#
# Ethane also extremely flammable dangerous inhale explosive .
#
#
# Both may cause suffocation .
#
#
# Similarly propane flammable explosive .
#
#
# It may cause drowsiness unconsciousness inhaled .
#
#
# Butane hazards consider propane .
#
#
# Alkanes also pose threat environment .
#
#
# Branched alkanes lower biodegradability unbranched alkanes .
#
#
# However methane ranked dangerous greenhouse gas .
#
#
# Although amount methane atmosphere low pose threat environment .
# .
#
#
# Coordinates 64°N 150°W﻿ ﻿64°N 150°W﻿ 64 150 Alaska Aleut Alax̂sxax̂ Inupiaq Alaasikaq Alutiiq Alaskaaq Tlingit Anáaski Russian Аляска romanized Alyaska state located northwest extremity United States West Coast across Bering Strait Asia .
#
#
# An exclave U.S. borders Canadian province British Columbia territory Yukon east southeast maritime border Russia s Chukotka Autonomous Okrug west .
#
#
# To north Chukchi Beaufort seas Arctic Ocean Pacific Ocean lies south southwest .
#
#
# Alaska largest U.S. state area seventh largest subnational division world .
#
#
# It third least populous sparsely populated state far continent s populous territory located mostly north 60th parallel estimated population 738432 2015—more quadruple combined populations Northern Canada Greenland .
#
#
# Approximately half Alaska s residents live within Anchorage metropolitan area .
#
#
# The state capital Juneau second largest city United States area comprising territory states Rhode Island Delaware .
#
#
# Alaska occupied various indigenous peoples thousands years arrival Europeans .
#
#
# The state considered entry point settlement North America way Bering land bridge .
#
#
# The Russians first nonnative people settle area beginning 18th century eventually establishing colony Alaska spanned current state .
#
#
# The expense difficulty maintaining distant possession prompted sale U.S. 1867 7.2 million approximately two cents per acre .
#
#
# The area went several administrative changes becoming organized territory May 11 1912 .
#
#
# It admitted 49th state U.S. January 3 1959 .
#
#
# While one smallest state economies country Alaska s per capita income among highest owing diversified economy dominated fishing natural gas oil abundance .
#
#
# United States armed forces bases tourism also significant part economy half state federally owned public land including multitude national forests parks wildlife refuges .
#
#
# Alaska s indigenous population proportionally highest U.S. state 15 percent .
#
#
# Close two dozen native languages spoken Alaskan Natives exercise considerable influence local state politics .
#
#
# The name Alaska introduced Russian colonial period used refer Alaska Peninsula .
#
#
# It derived Aleutlanguage idiom figuratively refers mainland .
#
#
# Literally means object action sea directed .
#
#
# Alaska northernmost westernmost state United States easterly longitude United States Aleutian Islands extend Eastern Hemisphere .
#
#
# Alaska noncontiguous U.S. state continental North America 500 miles British Columbia separates Alaska Washington .
#
#
# It technically part continental U.S. sometimes included colloquial use Alaska part contiguous U.S. often called Lower 48 .
#
#
# The capital city Juneau situated mainland North American continent connected road rest North American highway system .
#
#
# The state bordered Canada s Yukon British Columbia east Gulf Alaska Pacific Ocean south southwest Bering Sea Bering Strait Chukchi Sea west Arctic Ocean north .
#
#
# Alaska s territorial waters touch Russia s territorial waters Bering Strait Russian Big Diomede Island Alaskan Little Diomede Island 3 miles apart .
#
#
# Alaska longer coastline U.S. states combined .
#
#
# Alaska largest state United States total area .
#
#
# At 663268 square miles twice size Texas and—counting territorial waters—larger Texas California Montana combined .
#
#
# There officially defined borders demarcating various regions Alaska six widely accepted regions The populous region Alaska containing Anchorage MatanuskaSusitna Valley Kenai Peninsula .
#
#
# Rural mostly unpopulated areas south Alaska Range west Wrangell Mountains also fall within definition South Central Prince William Sound area communities Cordova Valdez .
#
#
# Also referred Panhandle Inside Passage region Alaska closest rest United States .
#
#
# As initial nonindigenous settlement occurred years following Alaska Purchase .
#
#
# The region dominated Alexander Archipelago well Tongass National Forest largest national forest United States .
#
#
# It contains state capital Juneau former capital Sitka Ketchikan one time Alaska s largest city .
#
#
# The Alaska Marine Highway provides vital surface transportation link throughout area three communities enjoy direct connections contiguous North American road system .
#
#
# Officially designated 1963 .
#
#
# The Interior largest region Alaska much uninhabited wilderness .
#
#
# Fairbanks large city region .
#
#
# Denali National Park Preserve located .
#
#
# Denali highest mountain North America .
#
#
# Southwest Alaska sparsely inhabited region stretching 500 miles inland Bering Sea .
#
#
# Most population lives along coast .
#
#
# Kodiak Island also located Southwest .
#
#
# The massive Yukon–Kuskokwim Delta one largest river deltas world .
#
#
# Portions Alaska Peninsula considered part Southwest remaining portions included Aleutian Islands .
#
#
# The North Slope mostly tundra peppered small villages .
#
#
# The area known massive reserves crude oil contains National Petroleum Reserve–Alaska Prudhoe Bay Oil Field .
#
#
# The city Utqiagvik formerly known Barrow northernmost city United States located .
#
#
# The Northwest Arctic area anchored Kotzebue also containing Kobuk River valley often regarded part region .
#
#
# However respective Inupiat North Slope Northwest Arctic seldom consider one people .
#
#
# More 300 small volcanic islands make chain stretches 1200 miles Pacific Ocean .
#
#
# Some islands fall Eastern Hemisphere International Date Line drawn west 180° keep whole state thus entire North American continent within legal day .
#
#
# Two islands Attu Kiska occupied Japanese forces World War II .
#
#
# With myriad islands Alaska nearly 34000 miles tidal shoreline .
#
#
# The Aleutian Islands chain extends west southern tip Alaska Peninsula .
#
#
# Many active volcanoes found Aleutians coastal regions .
#
#
# Unimak Island example home Mount Shishaldin occasionally smoldering volcano rises 10000 feet North Pacific .
#
#
# It perfect volcanic cone Earth even symmetrical Japan s Mount Fuji .
#
#
# The chain volcanoes extends Mount Spurr west Anchorage mainland .
#
#
# Geologists identified Alaska part Wrangellia large region consisting multiple states Canadian provinces Pacific Northwest actively undergoing continent building .
#
#
# One world s largest tides occurs Turnagain Arm south Anchorage tidal differences 35 feet .
#
#
# Alaska three million lakes .
#
#
# Marshlands wetland permafrost cover 188320 square miles .
#
#
# Glacier ice covers 28957 square miles Alaska .
#
#
# The Bering Glacier largest glacier North America covering 2008 square miles alone .
#
#
# According October 1998 report United States Bureau Land Management approximately 65 Alaska owned managed U.S. federal government public lands including multitude national forests national parks national wildlife refuges .
#
#
# Of Bureau Land Management manages 87 million acres 23.8 state .
#
#
# The Arctic National Wildlife Refuge managed United States Fish Wildlife Service .
#
#
# It world s largest wildlife refuge comprising 16 million acres .
#
#
# Of remaining land area state Alaska owns 101 million acres entitlement Alaska Statehood Act .
#
#
# A portion acreage occasionally ceded organized boroughs statutory provisions pertaining newly formed boroughs .
#
#
# Smaller portions set aside rural subdivisions homesteadingrelated opportunities .
#
#
# These popular due often remote roadless locations .
#
#
# The University Alaska land grant university also owns substantial acreage manages independently .
#
#
# Another 44 million acres owned 12 regional scores local Native corporations created Alaska Native Claims Settlement Act 1971 .
#
#
# Regional Native corporation Doyon Limited often promotes largest private landowner Alaska advertisements communications .
#
#
# Provisions ANCSA allowing corporations land holdings sold open market starting 1991 repealed could take effect .
#
#
# Effectively corporations hold title sell land .
#
#
# Individual Native allotments sold open market however .
#
#
# Various private interests remaining land totaling one percent state .
#
#
# Alaska large margin state smallest percentage private land ownership Native corporation holdings excluded .
#
#
# The climate Southeast Alaska midlatitude oceanic climate southern sections subarctic oceanic climate northern parts .
#
#
# On annual basis Southeast wettest warmest part Alaska milder temperatures winter high precipitation throughout year .
#
#
# Juneau averages 50 precipitation year Ketchikan averages 150 .
#
#
# This also region Alaska average daytime high temperature freezing winter months .
#
#
# The climate Anchorage south central Alaska mild Alaskan standards due region s proximity seacoast .
#
#
# While area gets less rain southeast Alaska gets snow days tend clearer .
#
#
# On average Anchorage receives 16 precipitation year around 75 snow although areas south central receive far snow .
#
#
# It subarctic climate due brief cool summers .
#
#
# The climate Western Alaska determined large part Bering Sea Gulf Alaska .
#
#
# It subarctic oceanic climate southwest continental subarctic climate farther north .
#
#
# The temperature somewhat moderate considering far north area .
#
#
# This region tremendous amount variety precipitation .
#
#
# An area stretching northern side Seward Peninsula Kobuk River valley technically desert portions receiving less 10 precipitation annually .
#
#
# On extreme locations Dillingham Bethel average around 100 precipitation .
#
#
# The climate interior Alaska subarctic .
#
#
# Some highest lowest temperatures Alaska occur around area near Fairbanks .
#
#
# The summers may temperatures reaching 90s °F winter temperature fall −60 °F .
#
#
# Precipitation sparse Interior often less 10 year precipitation falls winter tends stay entire winter .
#
#
# The highest lowest recorded temperatures Alaska Interior .
#
#
# The highest 100 °F Fort Yukon June 27 1915 making Alaska tied Hawaii state lowest high temperature United States .
# The lowest official Alaska temperature −80 °F Prospect Creek January 23 1971 one degree lowest temperature recorded continental North America .
#
#
# The climate extreme north Alaska Arctic long cold winters short cool summers .
#
#
# Even July average low temperature Utqiagvik 34 °F .
#
#
# Precipitation light part Alaska many places averaging less 10 per year mostly snow stays ground almost entire year .
#
#
# Numerous indigenous peoples occupied Alaska thousands years arrival European peoples area .
#
#
# Linguistic DNA studies done provided evidence settlement North America way Bering land bridge .
#
#
# At Upward Sun River site Tanana River Valley Alaska remains sixweekold infant found .
#
#
# The baby s DNA showed belonged population genetically separate native groups present elsewhere New World end Pleistocene .
#
#
# Ben Potter University Alaska Fairbanks archaeologist unearthed remains Upward River Sun site 2013 named new group Ancient Beringians .
#
#
# The Tlingit people developed society matrilineal kinship system property inheritance descent today Southeast Alaska along parts British Columbia Yukon .
#
#
# Also Southeast Haida well known unique arts .
#
#
# The Tsimshian people came Alaska British Columbia 1887 President Grover Cleveland later U.S. Congress granted permission settle Annette Island found town Metlakatla .
#
#
# All three peoples well indigenous peoples Pacific Northwest Coast experienced smallpox outbreaks late 18th mid19th century devastating epidemics occurring 1830s 1860s resulting high fatalities social disruption .
#
#
# The Aleutian Islands still home Aleut people s seafaring society although first Native Alaskans exploited Russians .
#
#
# Western Southwestern Alaska home Yupik cousins Alutiiq Sugpiaq lived Southcentral Alaska .
#
#
# The Gwichin people northern Interior region Athabaskan primarily known today dependence caribou within muchcontested Arctic National Wildlife Refuge .
#
#
# The North Slope Little Diomede Island occupied widespread Inupiat people .
#
#
# Some researchers believe first Russian settlement Alaska established 17th century .
#
#
# According hypothesis 1648 several koches Semyon Dezhnyov s expedition came ashore Alaska storm founded settlement .
#
#
# This hypothesis based testimony Chukchi geographer Nikolai Daurkin visited Alaska 1764–1765 reported village Kheuveren River populated bearded men pray icons .
#
#
# Some modern researchers associate Kheuveren Koyuk River .
#
#
# The first European vessel reach Alaska generally held St. Gabriel authority surveyor M. S. Gvozdev assistant navigator I. Fyodorov August 21 1732 expedition Siberian cossak A. F. Shestakov Russian explorer Dmitry Pavlutsky .
#
#
# Another European contact Alaska occurred 1741 Vitus Bering led expedition Russian Navy aboard St. Peter .
#
#
# After crew returned Russia sea otter pelts judged finest fur world small associations fur traders began sail shores Siberia toward Aleutian Islands .
#
#
# The first permanent European settlement founded 1784 .
#
#
# Between 1774 1800 Spain sent several expeditions Alaska order assert claim Pacific Northwest .
#
#
# In 1789 Spanish settlement fort built Nootka Sound .
#
#
# These expeditions gave names places Valdez Bucareli Sound Cordova .
#
#
# Later RussianAmerican Company carried expanded colonization program earlytomid19th century .
#
#
# Sitka renamed New Archangel 1804 1867 Baranof Island Alexander Archipelago Southeast Alaska became capital Russian America .
#
#
# It remained capital colony transferred United States .
#
#
# The Russians never fully colonized Alaska colony never profitable .
#
#
# Evidence Russian settlement names churches survive throughout southeast Alaska .
#
#
# On March 30 1867 United States purchased Alaska Russian Empire sum 7.2 million .
#
#
# It another six months commissioners arrived Sitka formal transfer arranged .
#
#
# The formal flagraising took place Fort Sitka October 18 1867 .
#
#
# The original ceremony included 250 uniformed U.S. soldiers marched governor s house Castle Hill .
#
#
# Here Russian troops lowered Russian flag U.S. flag raised .
#
#
# This event celebrated Alaska Day legal holiday October 18 .
#
#
# William H. Seward United States Secretary State negotiated Alaska Purchase Russians 1867 7.2 million .
#
#
# Alaska loosely governed military initially administered district starting 1884 governor appointed President United States .
#
#
# A federal district court headquartered Sitka .
#
#
# For Alaska s first decade United States flag Sitka community inhabited American settlers .
#
#
# They organized provisional city government Alaska s first municipal government legal sense .
#
#
# Legislation allowing Alaskan communities legally incorporate cities come 1900 home rule cities extremely limited unavailable statehood took effect 1959 .
#
#
# Starting 1890s stretching places early 1910s gold rushes Alaska nearby Yukon Territory brought thousands miners settlers Alaska .
#
#
# Alaska officially incorporated organized territory 1912 .
#
#
# Alaska s capital Sitka 1906 moved north Juneau .
#
#
# Construction Alaska Governor s Mansion began year .
#
#
# European immigrants Norway Sweden also settled southeast Alaska entered fishing logging industries .
#
#
# During World War II Aleutian Islands Campaign focused Attu Agattu Kiska .
#
#
# During occupation one Aleut civilian killed nearly fifty interned Japan half died .
#
#
# UnalaskaDutch Harbor became significant base United States Army Air Forces Navy submariners .
#
#
# The United States LendLease program involved flying American warplanes Canada Fairbanks Nome Soviet pilots took possession aircraft ferrying fight German invasion Soviet Union .
#
#
# The construction military bases contributed population growth Alaskan cities .
#
#
# Statehood Alaska important cause James Wickersham early tenure congressional delegate .
#
#
# Decades later statehood movement gained first real momentum following territorial referendum 1946 .
#
#
# The Alaska Statehood Committee Alaska s Constitutional Convention would soon follow .
#
#
# Statehood supporters also found fighting major battles political foes mostly U.S. Congress also within Alaska .
#
#
# Statehood approved Congress July 7 1958 .
#
#
# Alaska officially proclaimed state January 3 1959 .
#
#
# In 1960 Census Bureau reported Alaska s population 77.2 White 3 Black 18.8 American Indian Alaska Native .
#
#
# On March 27 1964 massive Good Friday earthquake killed 133 people destroyed several villages portions large coastal communities mainly resultant tsunamis landslides .
#
#
# It secondmostpowerful earthquake recorded history moment magnitude 9.2 .
#
#
# The time day time year location epicenter cited factors potentially sparing thousands lives particularly Anchorage .
#
#
# The 1968 discovery oil Prudhoe Bay 1977 completion TransAlaska Pipeline System led oil boom .
#
#
# Royalty revenues oil funded large state budgets 1980 onward .
#
#
# That year coincidentally Alaska repealed state income tax .
#
#
# In 1989 Exxon Valdez hit reef Prince William Sound spilling 11 million U.S. gallons crude oil 1100 miles coastline .
#
#
# Today battle philosophies development conservation seen contentious debate oil drilling Arctic National Wildlife Refuge proposed Pebble Mine .
#
#
# The Alaska Heritage Resources Survey restricted inventory reported historic prehistoric sites within state Alaska maintained Office History Archaeology .
#
#
# The survey s inventory cultural resources includes objects structures buildings sites districts travel ways general provision fifty years old .
#
#
# As January 31 2012 35000 sites reported .
#
#
# The United States Census Bureau estimates population Alaska 737438 July 1 2018 3.83 increase since 2010 United States Census .
#
#
# In 2010 Alaska ranked 47th state population ahead North Dakota Vermont Wyoming .
#
#
# Estimates show North Dakota ahead 2018 .
#
#
# Alaska least densely populated state one sparsely populated areas world 1.2 inhabitants per square mile next state Wyoming 5.8 inhabitants per square mile .
#
#
# Alaska far largest U.S. state area tenth wealthiest .
#
#
# As November 2014 state s unemployment rate 6.6 .
#
#
# As 2018 one 14 U.S. states still one telephone area code .
#
#
# According 2010 United States Census Alaska population 710231 .
#
#
# In terms race ethnicity state 66.7 White 14.8 American Indian Alaska Native 5.4 Asian 3.3 Black African American 1.0 Native Hawaiian Other Pacific Islander 1.6 Some Other Race 7.3 Two More Races .
#
#
# Hispanics Latinos race made 5.5 population .
#
#
# As 2011 50.7 Alaska s population younger one year age belonged minority groups .
# According 2011 American Community Survey 83.4 people age five spoke English home .
#
#
# About 3.5 spoke Spanish home 2.2 spoke another IndoEuropean language 4.3 spoke Asian language 5.3 spoke languages home .
#
#
# The Alaska Native Language Center University Alaska Fairbanks claims least 20 Alaskan native languages exist also languages different dialects .
#
#
# Most Alaska s native languages belong either Eskimo–Aleut NaDene language families however languages thought isolates yet classified .
#
#
# As 2014 nearly Alaska s native languages classified either threatened shifting moribund nearly extinct dormant languages .
#
#
# A total 5.2 Alaskans speak one state s 20 indigenous languages known locally native languages .
#
#
# In October 2014 governor Alaska signed bill declaring state s 20 indigenous languages official status .
#
#
# This bill gave symbolic recognition official languages though adopted official use within government .
#
#
# The 20 languages included bill According statistics collected Association Religion Data Archives 2010 34 Alaska residents members religious congregations .
#
#
# 100960 people identified Evangelical Protestants 50866 Roman Catholic 32550 mainline Protestants .
#
#
# Roughly 4 Mormon 0.5 Jewish 1 Muslim 0.5 Buddhist 0.2 Bahá í 0.5 Hindu .
#
#
# The largest religious denominations Alaska 2010 Catholic Church 50866 adherents nondenominational Evangelical Protestants 38070 adherents The Church Jesus Christ Latterday Saints 32170 adherents Southern Baptist Convention 19891 adherents .
#
#
# Alaska identified along Pacific Northwest states Washington Oregon least religious states USA terms church membership In 1795 First Russian Orthodox Church established Kodiak .
#
#
# Intermarriage Alaskan Natives helped Russian immigrants integrate society .
#
#
# As result increasing number Russian Orthodox churches gradually became established within Alaska .
#
#
# Alaska also largest Quaker population state .
#
#
# In 2009 6000 Jews Alaska .
#
#
# Alaskan Hindus often share venues celebrations members Asian religious communities including Sikhs Jains..
#
#
# ...
#
#
# The smallest towns villages must rely scheduled chartered bush flying services using general aviation aircraft Cessna Caravan popular aircraft use state .
#
#
# Much service attributed Alaska bypass mail program subsidizes bulk mail delivery Alaskan rural communities .
#
#
# The program requires 70 subsidy go carriers offer passenger service communities .
#
#
# Many communities small air taxi services .
#
#
# These operations originated demand customized transport remote areas .
#
#
# Perhaps quintessentially Alaskan plane bush seaplane .
#
#
# The world s busiest seaplane base Lake Hood located next Ted Stevens Anchorage International Airport flights bound remote villages without airstrip carry passengers cargo many items stores warehouse clubs .
#
#
# In 2006 Alaska highest number pilots per capita U.S. state .
#
#
# Another Alaskan transportation method dogsled .
#
#
# In modern times dog mushing sport true means transportation .
#
#
# Various races held around state best known Iditarod Trail Sled Dog Race 1150mile trail Anchorage Nome .
#
#
# The race commemorates famous 1925 serum run Nome mushers dogs like Togo Balto took muchneeded medicine diphtheriastricken community Nome means transportation failed .
#
#
# Mushers world come Anchorage March compete cash prizes prestige .
#
#
# The Serum Run another sled dog race accurately follows route famous 1925 relay leaving community Nenana Nome .
#
#
# In areas served road rail primary transportation summer allterrain vehicle winter snowmobile snow machine commonly referred Alaska .
#
#
# Alaska s internet data transport systems provided largely two major telecommunications companies GCI Alaska Communications .
#
#
# GCI owns operates calls Alaska United Fiber Optic system late 2011 Alaska Communications advertised two fiber optic paths lower 48 two across Alaska .
#
#
# In January 2011 reported 1 billion project connect Asia rural Alaska planned aided part 350 million stimulus federal government .
#
#
# Like U.S. states Alaska governed republic three branches government executive branch consisting governor Alaska appointees head executive departments legislative branch consisting Alaska House Representatives Alaska Senate judicial branch consisting Alaska Supreme Court lower courts .
#
#
# The state Alaska employs approximately 16000 people statewide .
#
#
# The Alaska Legislature consists 40member House Representatives 20member Senate .
#
#
# Senators serve fouryear terms House members two .
#
#
# The governor Alaska serves fouryear terms .
#
#
# The lieutenant governor runs separately governor primaries general election nominee governor nominee lieutenant governor run together ticket .
#
#
# Alaska s court system four levels Alaska Supreme Court Alaska Court Appeals superior courts district courts .
#
#
# The superior district courts trial courts .
#
#
# Superior courts courts general jurisdiction district courts hear certain types cases including misdemeanor criminal cases civil cases valued 100000 .
#
#
# The Supreme Court Court Appeals appellate courts .
#
#
# The Court Appeals required hear appeals certain lowercourt decisions including regarding criminal prosecutions juvenile delinquency habeas corpus .
#
#
# The Supreme Court hears civil appeals may discretion hear criminal appeals .
#
#
# Although early years statehood Alaska Democratic state since early 1970s characterized Republicanleaning .
#
#
# Local political communities often worked issues related land use development fishing tourism individual rights .
#
#
# Alaska Natives organized around communities active within Native corporations .
#
#
# These given ownership large tracts land require stewardship .
#
#
# Alaska formerly state possession one ounce less marijuana one s home completely legal state law though federal law remains force .
#
#
# The state independence movement favoring vote secession United States Alaskan Independence Party .
#
#
# Six Republicans four Democrats served governor Alaska .
#
#
# In addition Republican governor Wally Hickel elected office second term 1990 leaving Republican party briefly joining Alaskan Independence Party ticket long enough reelected .
# He officially rejoined Republican party 1994 .
#
#
# Alaska s voter initiative making marijuana legal took effect February 24 2015 placing Alaska alongside Colorado Washington first three U.S. states recreational marijuana legal .
#
#
# The new law means people 21 consume small amounts pot—if find .
#
#
# The first legal marijuana store opened Valdez October 2016 .
#
#
# To finance state government operations Alaska depends primarily petroleum revenues federal subsidies .
#
#
# This allows lowest individual tax burden United States .
#
#
# It one five states sales tax one seven states individual income tax state neither .
#
#
# The Department Revenue Tax Division reports regularly state s revenue sources .
#
#
# The Department also issues annual summary operations including new state laws directly affect tax division .
#
#
# While Alaska state sales tax 89 municipalities collect local sales tax 1.0–7.5 typically 3–5 .
#
#
# Other local taxes levied include raw fish taxes hotel motel bedandbreakfast bed taxes severance taxes liquor tobacco taxes gaming taxes tire taxes fuel transfer taxes .
#
#
# A part revenue collected certain state taxes license fees shared municipalities Alaska .
#
#
# Fairbanks one highest property taxes state sales income taxes assessed Fairbanks North Star Borough .
#
#
# A sales tax FNSB voted many times yet approved leading lawmakers increase taxes dramatically goods liquor tobacco .
#
#
# In 2014 Tax Foundation ranked Alaska fourth business friendly tax policy behind Wyoming South Dakota Nevada .
#
#
# Alaska regularly supports Republicans presidential elections done since statehood .
#
#
# Republicans state s electoral college votes one election participated .
#
#
# No state voted Democratic presidential candidate fewer times .
#
#
# Alaska carried Democratic nominee Lyndon B. Johnson landslide election 1964 1960 1968 elections close .
#
#
# Since 1972 however Republicans carried state large margins .
#
#
# In 2008 Republican John McCain defeated Democrat Barack Obama Alaska 59.49 37.83 .
#
#
# McCain s running mate Sarah Palin state s governor first Alaskan major party ticket .
#
#
# Obama lost Alaska 2012 captured 40 state s vote election making first Democrat since 1968 .
#
#
# The Alaska Bush central Juneau midtown downtown Anchorage areas surrounding University Alaska Fairbanks campus Ester strongholds Democratic Party .
#
#
# The MatanuskaSusitna Borough majority Fairbanks South Anchorage typically strongest Republican showing .
#
#
# As 2004 well half registered voters chosen nonpartisan undeclared affiliation despite recent attempts close primaries unaffiliated voters .
#
#
# Because population relative U.S. states Alaska one member U.S. House Representatives .
#
#
# This seat held Republican Don Young reelected 21st consecutive term 2012 .
#
#
# Alaska s atlarge congressional district one largest parliamentary constituencies world area .
#
#
# In 2008 Governor Sarah Palin became first Republican woman run national ticket became John McCain s running mate .
#
#
# She continued prominent national figure even resigning governor s job July 2009 .
#
#
# Alaska s United States senators belong Class 2 Class 3 .
#
#
# In 2008 Democrat Mark Begich mayor Anchorage defeated longtime Republican senator Ted Stevens .
#
#
# Stevens convicted seven felony counts failing report gifts Senate financial discloser forms one week election .
#
#
# The conviction set aside April 2009 evidence prosecutorial misconduct emerged .
#
#
# Republican Frank Murkowski held state s senatorial position .
#
#
# After elected governor 2002 resigned Senate appointed daughter State representative Lisa Murkowski successor .
#
#
# She full sixyear terms 2004 2010 2016 .
#
#
# Mike Dunleavy Governor Lisa Murkowski senior United States Senator Dan Sullivan junior United States Senator Don Young United States Representative Alaska divided counties U.S. states divided boroughs .
#
#
# Many densely populated parts state part Alaska s 16 boroughs function somewhat similarly counties states .
#
#
# However unlike countyequivalents 49 states boroughs cover entire land area state .
#
#
# The area part borough referred Unorganized Borough .
#
#
# The Unorganized Borough government U.S. Census Bureau cooperation state divided Unorganized Borough 11 census areas solely purposes statistical analysis presentation .
#
#
# A recording district mechanism administration public record Alaska .
#
#
# The state divided 34 recording districts centrally administered State Recorder .
#
#
# All recording districts use acceptance criteria fee schedule etc.
#
#
# accepting documents public record .
#
#
# Whereas many U.S. states use threetiered system decentralization—statecountytownship—most Alaska uses two tiers—stateborough .
#
#
# Owing low population density land located Unorganized Borough .
#
#
# As name implies intermediate borough government administered directly state government .
#
#
# In 2000 57.71 Alaska s area status 13.05 population .
#
#
# Anchorage merged city government Greater Anchorage Area Borough 1975 form Municipality Anchorage containing city proper communities Eagle River Chugiak Peters Creek Girdwood Bird Indian .
#
#
# Fairbanks separate borough municipality .
#
#
# The state s populous city Anchorage home 278700 people 2006 225744 live urbanized area .
#
#
# The richest location Alaska per capita income Halibut Cove .
#
#
# Yakutat City Sitka Juneau Anchorage four largest cities U.S. area .
#
#
# As reflected 2010 United States Census Alaska total 355 incorporated cities censusdesignated places .
#
#
# The tally cities includes four unified municipalities essentially equivalent consolidated city–county .
#
#
# The majority communities located rural expanse Alaska known The Bush unconnected contiguous North American road network .
#
#
# The table bottom section lists 100 largest cities censusdesignated places Alaska population order .
#
#
# Of Alaska s 2010 Census population figure 710231 20429 people 2.88 population live incorporated city censusdesignated place .
#
#
# Approximately threequarters figure people live urban suburban neighborhoods outskirts city limits Ketchikan Kodiak Palmer Wasilla .
#
#
# CDPs established areas United States Census Bureau except seven CDPs established Ketchikanarea neighborhoods 1980 Census used since .
#
#
# The remaining population scattered throughout Alaska within organized boroughs Unorganized Borough largely remote areas .
#
#
# The Alaska Department Education Early Development administers many school districts Alaska .
#
#
# In addition state operates boarding school Mt .
#
#
# Edgecumbe High School Sitka provides partial funding boarding schools including Nenana Student Living Center Nenana The Galena Interior Learning Academy Galena .
#
#
# There dozen colleges universities Alaska .
#
#
# Accredited universities Alaska include University Alaska Anchorage University Alaska Fairbanks University Alaska Southeast Alaska Pacific University .
#
#
# Alaska state institutions part NCAA Division I .
#
#
# The Alaska Department Labor Workforce Development operates AVTEC Alaska s Institute Technology .
#
#
# Campuses Seward Anchorage offer oneweek 11month training programs areas diverse Information Technology Welding Nursing Mechanics .
#
#
# Alaska problem brain drain .
#
#
# Many young people including highest academic achievers leave state high school graduation return .
#
#
# As 2013 Alaska law school medical school .
#
#
# The University Alaska attempted combat offering partial fouryear scholarships top 10 Alaska high school graduates via Alaska Scholars Program .
#
#
# The Alaska State Troopers Alaska s statewide police force .
#
#
# They long storied history official organization 1941 .
#
#
# Before force officially organized law enforcement Alaska handled various federal agencies .
#
#
# Larger towns usually local police villages rely Public Safety Officers police training carry firearms .
#
#
# In much state troopers serve police force available .
#
#
# In addition enforcing traffic criminal law wildlife Troopers enforce hunting fishing regulations .
#
#
# Due varied terrain wide scope Troopers duties employ wide variety land air water patrol vehicles .
#
#
# Many rural communities Alaska considered dry outlawed importation alcoholic beverages .
#
#
# Suicide rates rural residents higher urban .
#
#
# Domestic abuse violent crimes also high levels state part linked alcohol abuse .
#
#
# Alaska highest rate sexual assault nation especially rural areas .
#
#
# The average age sexually assaulted victims 16 years old .
#
#
# In four five cases suspects relatives friends acquaintances .
#
#
# Some Alaska s popular annual events Iditarod Trail Sled Dog Race Anchorage Nome World Ice Art Championships Fairbanks Blueberry Festival Alaska Hummingbird Festival Ketchikan Sitka Whale Fest Stikine River Garnet Fest Wrangell .
#
#
# The Stikine River attracts largest springtime concentration American bald eagles world .
#
#
# The Alaska Native Heritage Center celebrates rich heritage Alaska s 11 cultural groups .
#
#
# Their purpose encourage crosscultural exchanges among people enhance selfesteem among Native people .
#
#
# The Alaska Native Arts Foundation promotes markets Native art regions cultures State using internet .
#
#
# Influences music Alaska include traditional music Alaska Natives well folk music brought later immigrants Russia Europe .
#
#
# Prominent musicians Alaska include singer Jewel traditional Aleut flautist Mary Youngblood folk singersongwriter Libby Roderick Christian music singersongwriter Lincoln Brewster metalpost hardcore band 36 Crazyfists groups Pamyua Portugal .
#
#
# The Man .
#
#
# There many established music festivals Alaska including Alaska Folk Festival Fairbanks Summer Arts Festival Anchorage Folk Festival Athabascan OldTime Fiddling Festival Sitka Jazz Festival Sitka Summer Music Festival .
#
#
# The prominent orchestra Alaska Anchorage Symphony Orchestra though Fairbanks Symphony Orchestra Juneau Symphony also notable .
#
#
# The Anchorage Opera currently state s professional opera company though several volunteer semiprofessional organizations state well .
#
#
# The official state song Alaska Alaska s Flag adopted 1955 celebrates flag Alaska .
#
#
# Alaska s first independent picture entirely made Alaska The Chechahcos produced Alaskan businessman Austin E. Lathrop filmed around Anchorage .
#
#
# Released 1924 Alaska Moving Picture Corporation film company made .
#
#
# One prominent movies filmed Alaska MGM s EskimoMala The Magnificent starring Alaska Native Ray Mala .
#
#
# In 1932 expedition set MGM s studios Hollywood Alaska film billed The Biggest Picture Ever Made .
# Upon arriving Alaska set Camp Hollywood Northwest Alaska lived duration filming .
#
#
# Louis B. Mayer spared expense spite remote location going far hire chef Hotel Roosevelt Hollywood prepare meals .
#
#
# When Eskimo premiered Astor Theatre New York City studio received largest amount feedback history .
#
#
# Eskimo critically acclaimed released worldwide result Mala became international movie star .
#
#
# Eskimo first Oscar Best Film Editing Academy Awards showcased preserved aspects Inupiat culture film .
#
#
# The 1983 Disney movie Never Cry Wolf least partially shot Alaska .
#
#
# The 1991 film White Fang based Jack London s novel starring Ethan Hawke filmed around Haines .
#
#
# Steven Seagal s 1994 On Deadly Ground starring Michael Caine filmed part Worthington Glacier near Valdez .
#
#
# The 1999 John Sayles film Limbo starring David Strathairn Mary Elizabeth Mastrantonio Kris Kristofferson filmed Juneau .
#
#
# The psychological thriller Insomnia starring Al Pacino Robin Williams shot Canada set Alaska .
#
#
# The 2007 film directed Sean Penn Into The Wild partially filmed set Alaska .
#
#
# The film based novel name follows adventures Christopher McCandless died remote abandoned bus along Stampede Trail west Healy 1992 .
#
#
# Many films television shows set Alaska filmed example Northern Exposure set fictional town Cicely Alaska filmed Roslyn Washington .
#
#
# The 2007 horror feature 30 Days Night set Barrow Alaska filmed New Zealand .
#
#
# Many reality television shows filmed Alaska .
#
#
# In 2011 Anchorage Daily News found ten set state .
#
#
# .

# %%
sent = "IUPAC defines alkanes acyclic branched unbranched hydrocarbons general formula CnH2n2 therefore consisting entirely hydrogen atoms saturated carbon atoms."
doc = nlp(sent)
doc
# Out:
# IUPAC defines alkanes acyclic branched unbranched hydrocarbons general formula CnH2n2 therefore consisting entirely hydrogen atoms saturated carbon atoms.

# %%
for token in doc:
    print(f"{token.text:{15}} {token.tag_:{5}} {spacy.explain(token.tag_):{40}} {token.pos_:{10}} {token.dep_:{20}}")
# Out:
# IUPAC           NN    noun, singular or mass                   NOUN       compound
# defines         NNS   noun, plural                             NOUN       nsubj
# alkanes         VBZ   verb, 3rd person singular present        VERB       ROOT
# acyclic         NNP   noun, proper singular                    PROPN      nsubj
# branched        VBD   verb, past tense                         VERB       ccomp
# unbranched      JJ    adjective                                ADJ        amod
# hydrocarbons    NNS   noun, plural                             NOUN       nmod
# general         JJ    adjective                                ADJ        amod
# formula         NN    noun, singular or mass                   NOUN       dobj
# CnH2n2          NNP   noun, proper singular                    PROPN      punct
# therefore       RB    adverb                                   ADV        advmod
# consisting      VBG   verb, gerund or present participle       VERB       prep
# entirely        RB    adverb                                   ADV        advmod
# hydrogen        NN    noun, singular or mass                   NOUN       compound
# atoms           NNS   noun, plural                             NOUN       dobj
# saturated       VBN   verb, past participle                    VERB       amod
# carbon          NN    noun, singular or mass                   NOUN       compound
# atoms           NNS   noun, plural                             NOUN       dobj
# .               .     punctuation mark, sentence closer        PUNCT      punct

# %%
for ent in doc.ents:
    print(f"{ent.text:{10}} {ent.label_:{10}} {str(spacy.explain(ent.label_)):{50}}")

# %%
for chunk in doc.noun_chunks:
    print(chunk)
# Out:
# IUPAC defines
# acyclic
# unbranched hydrocarbons general formula
# hydrogen atoms
